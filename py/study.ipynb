# %%
orders=["milk","Bread","Eggs"]
print(orders)
# Out:
# ['milk', 'Bread', 'Eggs']

# %%
orders=["milk","Bread","Eggs"]
orders.append("Butter")
print(orders)
# Out:
# ['milk', 'Bread', 'Eggs', 'Butter']

# %%
orders=["milk","Bread","Eggs"]
orders.append("Butter")
orders.sort()
print(orders)
# Out:
# ['Bread', 'Butter', 'Eggs', 'milk']

# %%
orders=["milk","Bread","Eggs"]
orders.insert(1, "fruit")
print(orders)
# Out:
# ['milk', 'fruit', 'Bread', 'Eggs']

# %%
partner_orders=["rice","oil"]
orders.extend(partner_orders)
print(orders)
# Out:
# ['milk', 'fruit', 'Bread', 'Eggs', 'rice', 'oil']

# %%
orders=["milk","fruit","Bread","Eggs"]
print(orders[0])
# Out:
# milk

# %%
batch_orders=orders[1:3]
print(batch_orders)
# Out:
# ['fruit', 'Bread']

# %%
orders=["milk","Bread","Eggs"]
orders[orders.index("milk")]="amlond_milk"
print(orders)
# Out:
# ['amlond_milk', 'Bread', 'Eggs']

# %%
orders.remove("Bread")
print(orders)
# Out:
# ['amlond_milk', 'Eggs']

# %%
orders=["milk","Bread","Eggs"]
orders.insert(1, "fruit")
orders.remove("Bread")
print(orders)
# Out:
# ['milk', 'fruit', 'Eggs']

# %%
orders=["milk","Bread"]
orders.extend(["Eggs","Butter","Rice"])

print(orders[1:4])
# Out:
# ['Bread', 'Eggs', 'Butter']

# %%
orders=["Milk","Bread","Eggs"]
orders.insert(0, "Rice")
orders.sort()
print(orders[1:3])
# Out:
# ['Eggs', 'Milk']
